# %%
# pip install PyQt5

# %%
import random
import time
import pandas as pd
from PyQt5 import QtCore, QtGui, QtWidgets

class Ui_MainWindow(object):
    def setupUi(self, MainWindow):
        MainWindow.setObjectName("MainWindow")
        MainWindow.resize(500, 500)
        self.centralwidget = QtWidgets.QWidget(MainWindow)
        self.centralwidget.setObjectName("centralwidget")
        self.game_label = QtWidgets.QLabel(self.centralwidget)
        self.game_label.setGeometry(QtCore.QRect(110, 10, 400, 31))
        font = QtGui.QFont()
        font.setPointSize(16)
        self.game_label.setFont(font)
        self.game_label.setObjectName("game_label")
        self.rule_label = QtWidgets.QLabel(self.centralwidget)
        self.rule_label.setGeometry(QtCore.QRect(10, 50, 91, 31))
        font = QtGui.QFont()
        font.setPointSize(12)
        self.rule_label.setFont(font)
        self.rule_label.setObjectName("rule_label")
        self.pass_label = QtWidgets.QLabel(self.centralwidget)
        self.pass_label.setGeometry(QtCore.QRect(20, 80, 301, 31))
        font = QtGui.QFont()
        font.setPointSize(10)
        self.pass_label.setFont(font)
        self.pass_label.setObjectName("pass_label")
        self.end_label = QtWidgets.QLabel(self.centralwidget)
        self.end_label.setGeometry(QtCore.QRect(20, 110, 301, 31))
        font = QtGui.QFont()
        font.setPointSize(10)
        self.end_label.setFont(font)
        self.end_label.setObjectName("end_label")
        self.answer_label = QtWidgets.QLabel(self.centralwidget)
        self.answer_label.setGeometry(QtCore.QRect(20, 140, 311, 31))
        font = QtGui.QFont()
        font.setPointSize(10)
        self.answer_label.setFont(font)
        self.answer_label.setObjectName("answer_label")
        self.timer_label = QtWidgets.QLabel(self.centralwidget)
        self.timer_label.setGeometry(QtCore.QRect(310, 50, 101, 31))
        font = QtGui.QFont()
        font.setPointSize(12)
        self.timer_label.setFont(font)
        self.timer_label.setObjectName("timer_label")
        self.question_label = QtWidgets.QLabel(self.centralwidget)
        self.question_label.setGeometry(QtCore.QRect(30, 200, 311, 31))
        font = QtGui.QFont()
        font.setPointSize(12)
        self.question_label.setFont(font)
        self.question_label.setObjectName("question_label")
        self.answer_edit = QtWidgets.QLineEdit(self.centralwidget)
        self.answer_edit.setGeometry(QtCore.QRect(30, 250, 171, 31))
        font = QtGui.QFont()
        font.setPointSize(10)
        self.answer_edit.setFont(font)
        self.answer_edit.setObjectName("answer_edit")
        self.check_button = QtWidgets.QPushButton(self.centralwidget)
        self.check_button.setGeometry(QtCore.QRect(220, 250, 81, 31))
        self.check_button.setObjectName("check_button")
        self.next_button = QtWidgets.QPushButton(self.centralwidget)
        self.next_button.setGeometry(QtCore.QRect(320, 250, 81, 31))
        self.next_button.setObjectName("next_button")
        self.score_label = QtWidgets.QLabel(self.centralwidget)
        self.score_label.setGeometry(QtCore.QRect(330, 310, 91, 31))
        font = QtGui.QFont()
        font.setPointSize(12)
        self.score_label.setFont(font)
        self.score_label.setObjectName("score_label")
        MainWindow.setCentralWidget(self.centralwidget)

        self.retranslateUi(MainWindow)
        QtCore.QMetaObject.connectSlotsByName(MainWindow)

    def retranslateUi(self, MainWindow):
        _translate = QtCore.QCoreApplication.translate
        MainWindow.setWindowTitle(_translate("MainWindow", "빠른 단어 맞추기 게임"))
        self.game_label.setText(_translate("MainWindow", "빠른 단어 맞추기 게임"))
        self.rule_label.setText(_translate("MainWindow", "게임 규칙"))
        self.pass_label.setText(_translate("MainWindow", "1. 30초 동안 제시된 단어를 기억하세요."))
        self.end_label.setText(_translate("MainWindow", "2. 단어가 사라지면 단어를 입력하세요."))
        self.answer_label.setText(_translate("MainWindow", "3. 엔터키를 눌러 정답을 제출하세요."))
        self.timer_label.setText(_translate("MainWindow", "시간: 30"))
        self.question_label.setText(_translate("MainWindow", "단어:"))
        self.check_button.setText(_translate("MainWindow", "정답 확인"))
        self.next_button.setText(_translate("MainWindow", "다음 문제"))
        self.score_label.setText(_translate("MainWindow", "점수: 0"))
        
    # 정답 확인 버튼 누르면 실행될 함수
    def check_answer(self):
        # 사용자가 입력한 답
        user_answer = self.answer_edit.text()
        
        # 정답이면 score 증가
        if user_answer == self.correct_answer:
            self.score += 1
            self.update_score()
        
        # 다음 문제로 넘어감
        self.next_question()
    
    # 다음 문제로 넘어가는 함수
    def next_question(self):
        # 다음 문제의 번호 계산
        self.current_question_num += 1
        
        # 모든 문제를 다 푼 경우
        if self.current_question_num > self.total_question_num:
            self.end_game()
        else:
            # 다음 문제 출제
            self.show_question(self.current_question_num)
            # 타이머 시작
            self.start_timer()
    
    # 게임 종료 함수
    def end_game(self):
        # 타이머 정지
        self.timer.stop()
        
        # 메시지 박스 출력
        msg_box = QtWidgets.QMessageBox()
        msg_box.setWindowTitle("게임 종료")
        msg_box.setText("모든 문제를 푸셨습니다.")
        msg_box.setInformativeText(f"최종 점수: {self.score}")
        msg_box.setStandardButtons(QtWidgets.QMessageBox.Ok)
        msg_box.exec_()
        
        # 스코어 초기화 및 첫 번째 문제 출제
        self.score = 0
        self.show_question(1)

if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    MainWindow = QtWidgets.QMainWindow()
    ui = Ui_MainWindow()
    ui.setupUi(MainWindow)
    MainWindow.show()
    sys.exit(app.exec_())
